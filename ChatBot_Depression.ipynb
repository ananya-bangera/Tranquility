# %%
#

# %%
from newspaper import Article
import random 
import string
import nltk 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
nltk.download('punkt',quiet=True)
# Out:
# True

# %%
#Get the atricles OF DEPRESSION
article_depression1=Article('https://www.psychiatry.org/patients-families/depression/what-is-depression')
# article_depression2=Article('https://www.mayoclinic.org/diseases-conditions/depression/diagnosis-treatment/drc-20356013')
# article_depression3=Article('https://www.aafp.org/afp/2018/1015/p508.html')
article_depression1.download()
# article_depression2.download()
# article_depression3.download()
# article_depression1.parse()
article_depression1.nlp
# article_depression2.nlp
# article_depression3.nlp
corpus_depression_1=article_depression1.text
# corpus_depression_2=article_depression2.text
# corpus_depression_3=article_depression3.text

#Getting articles of ANXIETY
# article_anxiety1=Article('https://capmh.biomedcentral.com/articles/10.1186/s13034-017-0173-4')
# article_anxiety2=Article('https://adc.bmj.com/content/99/7/674')
# article_anxiety3=Article('https://www.healthline.com/health/anxiety-diagnosis#physical-exam')

# article_anxiety1.download()
# article_anxiety2.download()
# article_anxiety3.download()

# article_anxiety1.parse()
# article_anxiety2.parse()
# article_anxiety3.parse()


# article_anxiety1.nlp
# article_anxiety2.nlp
# article_anxiety3.nlp

# corpus_anxiety1=article_anxiety1.text
# corpus_anxiety2=article_anxiety2.text
# corpus_anxiety3=article_anxiety3.text

#Getting articles of STRESS
# article_stress1=Article('https://www.verywellfamily.com/reasons-why-your-teen-might-be-stressed-and-how-you-can-help-5197914')
# article_stress2=Article('https://www.verywellmind.com/signs-your-teen-is-stressed-out-2611336')
# article_stress3=Article('https://www.apa.org/topics/stress/children')
# article_stress4=Article('https://www.psycom.net/common-triggers-teen-stress/')

# article_stress1.download()
# article_stress2.download()
# article_stress3.download()
# article_stress4.download()

# article_stress1.parse()
# article_stress2.parse()
# article_stress3.parse()
# article_stress4.parse()

# article_stress1.nlp
# article_stress2.nlp
# article_stress3.nlp
# article_stress4.nlp

# corpus_stress1=article_stress1.text
# corpus_stress2=article_stress2.text
# corpus_stress3=article_stress3.text
# corpus_stress4=article_stress4.text

# %%
# print(corpus_anxiety2)
# print(corpus_anxiety1)
# print(corpus_anxiety3)
print(corpus_depression_1)
# print(corpus_depression_2)
# print(corpus_depression_3)
# Out:
# Keywords
#
# ...

# %%
#Tokenization
text= corpus_depression_1
#list of sentences
sentence_list=nltk.sent_tokenize(text)

# %%
#Print list of sentences
print(sentence_list)
# Out:
# ['Depression\n\nWhat Is Depression?', 'Depression (major depressive disorder) is a common and serious medical illness that negatively affects how you feel, the way you think and how you act.', 'Fortunately, it is also treatable.', 'Depression causes feelings of sadness and/or a loss of interest in activities you once enjoyed.', 'It can lead to a variety of emotional and physical problems and can decrease your ability to function at work and at home.', 'Depression symptoms can vary from mild to severe and can include:\n\nFeeling sad or having a depressed mood\n\nLoss of interest or pleasure in activities once enjoyed\n\nChanges in appetite — weight loss or gain unrelated to dieting\n\nTrouble sleeping or sleeping too much\n\nLoss of energy or increased fatigue\n\nIncrease in purposeless physical activity (e.g., inability to sit still, pacing, handwringing) or slowed movements or speech (these actions must be severe enough to be observable by others)\n\nFeeling worthless or guilty\n\nD
# ...

# %%
#fxn that returns greetings response to user greet
def greeting_response(text):
    text=text.lower()
    #Bot greeting response
    bot_greetings =['howdy', 'hi', 'hey','hello', 'hey there', 'hola']
    #user greeetings
    user_greetings= ['hi','hey','hello','hola','greetings', 'wassup']

    for word in text.split():
        if word in user_greetings:
            return random.choice(bot_greetings)

# %%
def index_sort(list_var):
    length=len(list_var)
    list_index= list(range(0,length))
    
    x=list_var
    for i in range(length):
        for j in range(length):
            if x[list_index[i]] >x[list_index[j]]:
                #Swap
                temp=list_index[i]
                list_index[i]= list_index[j]
                list[j]= temp

            return list_index

# %%
#create bot's response 
def bot_response(user_input):
    user_input = user_input.lower()
    sentence_list.append(user_input)
    bot_response= ''
    cm = CountVectorizer().fit_transform(sentence_list)
    similarity_scores= cosine_similarity(cm[-1],cm)
    similarity_scores_list=similarity_scores.flatten()
    index=index_sort(similarity_scores_list)
    index= index[1:]
    response_flag=0    

    j=0
    for i in range(len(index)):
        if similarity_scores_list[index[i]]>0.0:
            bot_response=bot_response+' '+sentence_list[index[i]]
            response_flag=1 
            j= j+1
        if j>2:
            break
        
        if response_flag==0:
            bot_response= bot_response+''+"I apologize, I dont understand"

        sentence_list.remove(user_input)
        return bot_response

# %%
#Start the Chat 
print('Doc Bot: I am a dOC that will help you improve your metal health....if you wanna to exit type bye ')

exit_list=['exit','see you later','bye','quit','break']

while(True):
    user_input=input()
    if user_input.lower() in exit_list:
        print("Doc Bot:Check with you later")
        break
    else:
        if greeting_response(user_input) !=None:
            print('DOC bot: '+greeting_response(user_input))
        else:
            print('Doc bot: '+bot_response(user_input))
# Out:
# Doc Bot: I am a dOC that will help you improve your metal health....if you wanna to exit type bye
# DOC bot: hola
# Doc bot:  Depression (major depressive disorder) is a common and serious medical illness that negatively affects how you feel, the way you think and how you act.
# Doc bot: I apologize, I dont understand
# Doc bot:  Depression (major depressive disorder) is a common and serious medical illness that negatively affects how you feel, the way you think and how you act.
# Doc bot: I apologize, I dont understand
